# %%
import pandas as pd 
import numpy as np

cancer = pd.read_csv('HEALTH_STAT_03092020141011281.csv')
cancer
# Out:
#            VAR                       Variable      UNIT  \
# 0     CANCTOCA            Malignant neoplasms  PERCMTTX
# 1     CANCTOCA            Malignant neoplasms  PERCMTTX
# 2     CANCTOCA            Malignant neoplasms  PERCMTTX
# 3     CANCCOLC   Malignant neoplasms of colon  PERCMTTX
# 4     CANCCOLC   Malignant neoplasms of colon  PERCMTTX
# ...        ...                            ...       ...
# 2971  CANCCOLC   Malignant neoplasms of colon  NBPOPIPC
# 2972  CANCLUNC    Malignant neoplasms of lung  PERCMTTX
# 2973  CANCCOLC   Malignant neoplasms of colon  INCITFTF
# 2974  CANCCEIX  Malignant neoplasms of cervix  NBWOMAPF
# 2975  CANCLUNC    Malignant neoplasms of lung  INCITHTH
#
#                                Measure  COU     Country   YEA  Year   Value  \
# 0     Incidence per 100 000 population  AUS   Australia  2002  2002   312.0
# 1     Incidence per 100 000 population  AUS   Australia  2008  2008   314.1
# 2     Incidence per 100 000 population  AUS   Australia  2012  2012   323.0
# 3     Incidence per 100 000 population  AUS   Australia  2002  2002    41.7
# 4     Incidence per 100 000 population  AUS   Australia  2008  2008    38.7
# ...                                ...  ...         ...   ...   ...     ...
# 2971             Number of total cases  COL    Colombia  2012  2012  5663.0
# 2972  Incidence per 100 000 population  LTU   Lithuania  2012  2012    26.2
# 2973     Incidence per 100 000 females  LTU   Lithuania  2012  2012    18.9
# 2974            Number of female cases  LTU   Lithuania  2012  2012   615.0
# 2975       Incidence per 100 000 males  CRI  Costa Rica  2012  2012     9.8
#
#       Flag Codes  Flags
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# ...          ...    ...
# 2971         NaN    NaN
# 2972         NaN    NaN
# 2973         NaN    NaN
# 2974         NaN    NaN
# 2975         NaN    NaN
#
# [2976 rows x 11 columns]

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   VAR         2976 non-null   object
#  1   Variable    2976 non-null   object
#  2   UNIT        2976 non-null   object
#  3   Measure     2976 non-null   object
#  4   COU         2976 non-null   object
#  5   Country     2976 non-null   object
#  6   YEA         2976 non-null   int64
#  7   Year        2976 non-null   int64
#  8   Value       2976 non-null   float64
#  9   Flag Codes  0 non-null      float64
#  10  Flags       0 non-null      float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 255.9+ KB

# %%
pd.set_option('display.max_columns', 75)
pd.set_option('display.max_rows', 75)

# %%
cancer.shape
# Out:
# (2976, 11)

# %%
cancer.head(15)
# Out:
#          VAR                      Variable      UNIT  \
# 0   CANCTOCA           Malignant neoplasms  PERCMTTX
# 1   CANCTOCA           Malignant neoplasms  PERCMTTX
# 2   CANCTOCA           Malignant neoplasms  PERCMTTX
# 3   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 4   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 5   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 6   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 7   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 8   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 9   CANCTOCA           Malignant neoplasms  PERCMTTX
# 10  CANCTOCA           Malignant neoplasms  PERCMTTX
# 11  CANCTOCA           Malignant neoplasms  PERCMTTX
# 12  CANCTOCA           Malignant neoplasms  PERCMTTX
# 13  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 14  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
#
#                              Measure  COU    Country   YEA  Year  Value  \
# 0   Incidence per 100 000 population  AUS  Australia  2002  2002  312.0
# 1   Incidence per 100 000 population  AUS  Australia  2008  2008  314.1
# 2   Incidence per 100 000 population  AUS  Australia  2012  2012  323.0
# 3   Incidence per 100 000 population  AUS  Australia  2002  2002   41.7
# 4   Incidence per 100 000 population  AUS  Australia  2008  2008   38.7
# 5   Incidence per 100 000 population  AUS  Australia  2012  2012   38.4
# 6   Incidence per 100 000 population  AUS  Australia  2002  2002   28.2
# 7   Incidence per 100 000 population  AUS  Australia  2008  2008   25.6
# 8   Incidence per 100 000 population  AUS  Australia  2012  2012   27.0
# 9   Incidence per 100 000 population  AUT    Austria  2000  2000  250.7
# 10  Incidence per 100 000 population  AUT    Austria  2002  2002  275.5
# 11  Incidence per 100 000 population  AUT    Austria  2008  2008  250.6
# 12  Incidence per 100 000 population  AUT    Austria  2012  2012  254.1
# 13  Incidence per 100 000 population  AUT    Austria  2000  2000   34.7
# 14  Incidence per 100 000 population  AUT    Austria  2002  2002   35.0
#
#     Flag Codes  Flags
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# 5          NaN    NaN
# 6          NaN    NaN
# 7          NaN    NaN
# 8          NaN    NaN
# 9          NaN    NaN
# 10         NaN    NaN
# 11         NaN    NaN
# 12         NaN    NaN
# 13         NaN    NaN
# 14         NaN    NaN

# %%
cancer.tail(15)
# Out:
#            VAR                         Variable      UNIT  \
# 2961  CANCTOCA              Malignant neoplasms  NBWOMAPF
# 2962  CANCTOCA              Malignant neoplasms  PERCMTTX
# 2963  CANCCOLC     Malignant neoplasms of colon  NBMANYPH
# 2964  CANCPROC  Malignant neoplasms of prostate  NBMANYPH
# 2965  CANCLUNC      Malignant neoplasms of lung  NBWOMAPF
# 2966  CANCCOLC     Malignant neoplasms of colon  INCITHTH
# 2967  CANCCEIX    Malignant neoplasms of cervix  INCITFTF
# 2968  CANCLUNC      Malignant neoplasms of lung  NBMANYPH
# 2969  CANCCEIX    Malignant neoplasms of cervix  INCITFTF
# 2970  CANCPROC  Malignant neoplasms of prostate  INCITHTH
# 2971  CANCCOLC     Malignant neoplasms of colon  NBPOPIPC
# 2972  CANCLUNC      Malignant neoplasms of lung  PERCMTTX
# 2973  CANCCOLC     Malignant neoplasms of colon  INCITFTF
# 2974  CANCCEIX    Malignant neoplasms of cervix  NBWOMAPF
# 2975  CANCLUNC      Malignant neoplasms of lung  INCITHTH
#
#                                Measure  COU     Country   YEA  Year    Value  \
# 2961            Number of female cases  COL    Colombia  2012  2012  37044.0
# 2962  Incidence per 100 000 population  LVA      Latvia  2012  2012    246.8
# 2963              Number of male cases  CRI  Costa Rica  2012  2012    404.0
# 2964              Number of male cases  COL    Colombia  2012  2012   9564.0
# 2965            Number of female cases  CRI  Costa Rica  2012  2012    130.0
# 2966       Incidence per 100 000 males  LVA      Latvia  2012  2012     30.0
# 2967     Incidence per 100 000 females  COL    Colombia  2012  2012     18.7
# 2968              Number of male cases  COL    Colombia  2012  2012   3038.0
# 2969     Incidence per 100 000 females  LTU   Lithuania  2012  2012     26.1
# 2970       Incidence per 100 000 males  CRI  Costa Rica  2012  2012     67.5
# 2971             Number of total cases  COL    Colombia  2012  2012   5663.0
# 2972  Incidence per 100 000 population  LTU   Lithuania  2012  2012     26.2
# 2973     Incidence per 100 000 females  LTU   Lithuania  2012  2012     18.9
# 2974            Number of female cases  LTU   Lithuania  2012  2012    615.0
# 2975       Incidence per 100 000 males  CRI  Costa Rica  2012  2012      9.8
#
#       Flag Codes  Flags
# 2961         NaN    NaN
# 2962         NaN    NaN
# 2963         NaN    NaN
# 2964         NaN    NaN
# 2965         NaN    NaN
# 2966         NaN    NaN
# 2967         NaN    NaN
# 2968         NaN    NaN
# 2969         NaN    NaN
# 2970         NaN    NaN
# 2971         NaN    NaN
# 2972         NaN    NaN
# 2973         NaN    NaN
# 2974         NaN    NaN
# 2975         NaN    NaN
