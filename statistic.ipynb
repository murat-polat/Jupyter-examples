# %%
import pandas as pd 
import numpy as np

cancer = pd.read_csv('HEALTH_STAT_03092020141011281.csv')
cancer=cancer.head(21)
cancer
# Out:
#          VAR                      Variable      UNIT  \
# 0   CANCTOCA           Malignant neoplasms  PERCMTTX
# 1   CANCTOCA           Malignant neoplasms  PERCMTTX
# 2   CANCTOCA           Malignant neoplasms  PERCMTTX
# 3   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 4   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 5   CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 6   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 7   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 8   CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 9   CANCTOCA           Malignant neoplasms  PERCMTTX
# 10  CANCTOCA           Malignant neoplasms  PERCMTTX
# 11  CANCTOCA           Malignant neoplasms  PERCMTTX
# 12  CANCTOCA           Malignant neoplasms  PERCMTTX
# 13  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 14  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 15  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 16  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# ...

# %%
custom_value = cancer[["Variable","Country","Year","Value"]]

# %%
custom_value
# Out:
#                         Variable    Country  Year  Value
# 0            Malignant neoplasms  Australia  2002  312.0
# 1            Malignant neoplasms  Australia  2008  314.1
# 2            Malignant neoplasms  Australia  2012  323.0
# 3   Malignant neoplasms of colon  Australia  2002   41.7
# 4   Malignant neoplasms of colon  Australia  2008   38.7
# 5   Malignant neoplasms of colon  Australia  2012   38.4
# 6    Malignant neoplasms of lung  Australia  2002   28.2
# 7    Malignant neoplasms of lung  Australia  2008   25.6
# 8    Malignant neoplasms of lung  Australia  2012   27.0
# 9            Malignant neoplasms    Austria  2000  250.7
# 10           Malignant neoplasms    Austria  2002  275.5
# 11           Malignant neoplasms    Austria  2008  250.6
# 12           Malignant neoplasms    Austria  2012  254.1
# 13  Malignant neoplasms of colon    Austria  2000   34.7
# 14  Malignant neoplasms of colon    Austria  2002   35.0
# ...
